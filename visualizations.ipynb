# %%
import pandas as pd
import numpy as np
import matplotlib

filepath = "/Users/terencemui/Documents/CS170/170-project2/data/CS170_Spring_2023_Small_data__95.txt"
df = pd.read_csv(filepath, delim_whitespace=True, header=None, engine="python")

features = [0, 4, 5]
subsetDf = df.iloc[:,features]
subsetDf.plot.scatter(4, 5, c=subsetDf.iloc[:,0], colorbar=True)
# Out:
# <Axes: xlabel='4', ylabel='5'>

# %%
filepath = "/Users/terencemui/Documents/CS170/170-project2/CS170_Spring_2023_Large_data__95.txt"
df = pd.read_csv(filepath, delim_whitespace=True, header=None, engine="python")

features = [0, 10, 19]
subsetDf = df.iloc[:,features]
subsetDf.plot.scatter(10, 19, c=subsetDf.iloc[:,0], colorbar=True)
